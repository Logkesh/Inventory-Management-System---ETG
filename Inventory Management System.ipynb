# %% [markdown]
# ## Inventory Management System

# %%
import json    #IMPORTING JSON TO HANDLE DICTIONARY

# %%
  #    THIS CELL WILL CREATES THE 'IMS.json' FILE AND WRITES THE DATA IN IT ON EXECUTION...
  #    OR WRITES THE DATA IN THE 'IMS.json' FILE IF THE FILE ALREADY EXIST.
products = {
    20210901 : {'name' : 'Diary Milk Silk Chocolate' , 'price' : 45.0, 'quantity' : 25 , 'category' : 'chocolate', 'net weight' : '175 g'},
    20210902 : {'name' : 'Diary Milk Silk Oreo' , 'price' : 40.0, 'quantity' : 25 , 'category' : 'chocolate', 'net weight' : '175 g'},
    20210903 : {'name' : 'Diary Milk Silk Plain' , 'price' : 35.0, 'quantity' : 25 , 'category' : 'chocolate', 'net weight' : '175 g'},
    20210904 : {'name' : 'Kurkure' , 'price' : 10.0, 'quantity' : 35 , 'category' : 'Snack', 'net weight' : '130 g'},
    20210905 : {'name' : 'Slice Mango Juice - 0.5 litre' , 'price' : 30.0, 'quantity' : 20 , 'category' : 'Juice', 'net weight' : '0.5 l'},
    20210906 : {'name' : 'Maaza Mango Juice - 0.5 litre' , 'price' : 32.0, 'quantity' : 24 , 'category' : 'Juice', 'net weight' : '0.5 l'},
    20210907 : {'name' : 'Unibic Cookies' , 'price' : 30.0, 'quantity' : 25 , 'category' : 'Biscuit', 'net weight' : '195 g'},
    20210908 : {'name' : 'Lote choco pie' , 'price' : 10.0, 'quantity' : 30 , 'category' : 'chocolate', 'net weight' : '170 g'},
    20210909 : {'name' : 'Kinder Joy' , 'price' : 35.0, 'quantity' : 28 , 'category' : 'chocolate', 'net weight' : '100 g'},
    20210910 : {'name' : 'Gems' , 'price' : 10.0, 'quantity' : 35 , 'category' : 'chocolate', 'net weight' : '100 g'},
    20210911 : {'name' : 'Parle G' , 'price' : 7.0,  'quantity' : 26 , 'category' : 'Biscuit', 'net weight' : '200 g'},
    20210912 : {'name' : 'Marie Gold' , 'price' : 10.0, 'quantity' : 20 , 'category' : 'Biscuit', 'net weight' : '200 g'},
    20210913 : {'name' : 'Marie Light' , 'price' : 10.0, 'quantity' : 20 , 'category' : 'Biscuit', 'net weight' : '210 g'},
    20210914 : {'name' : 'Happy Happy' , 'price' : 10.0, 'quantity' : 23 , 'category' : 'Biscuit', 'net weight' : '115 g'},
    20210915 : {'name' : 'Good Day' , 'price' : 10.0, 'quantity' : 25 , 'category' : 'Biscuit', 'net weight' : '95 g'},
    20210916 : {'name' : 'KitKat' , 'price' : 7.0,  'quantity' : 40 , 'category' : 'chocolate', 'net weight' : '75 g'},
    20210917 : {'name' : 'Milk Bikis' , 'price' : 15.0, 'quantity' : 38 , 'category' : 'chocolate', 'net weight' : '145 g'},
    20210918 : {'name' : 'Complan - 0.5 Kg' , 'price' : 495.0,'quantity' : 30 , 'category' : 'Nutrition Drink', 'net weight' : '500 g'},
    20210919 : {'name' : 'Pedia Sure - 0.5 Kg' , 'price' : 415.0,'quantity' : 32 , 'category' : 'Nutrition Drink', 'net weight' : '500 g'},
    20210920 : {'name' : 'Horliks - 0.5 Kg' , 'price' : 512.0,'quantity' : 36 , 'category' : 'Nutrition Drink', 'net weight' : '500 g'},
    20210921 : {'name' : 'Boost - 0.5 kg' , 'price' : 550.0,'quantity' : 25 , 'category' : 'Nutrition Drink', 'net weight' : '500 g'},
    20210922 : {'name' : 'Kalak\'s Chacos Chotta Laddoo' ,'price' : 10.0, 'quantity' : 45 , 'category' : 'Snack', 'net weight' : '315 g'},
    20210923 : {'name' : 'Kalak\'s Chacos Webs' , 'price' : 10.0, 'quantity' : 45 , 'category' : 'Snack', 'net weight' : '315 g'},
    20210924 : {'name' : 'Kalak\'s Chacos Frozen' , 'price' : 10.0, 'quantity' : 45 , 'category' : 'Snack', 'net weight' : '315 g'},
    20210925 : {'name' : 'Dark Fantasy Choco Fills' , 'price' : 25.0, 'quantity' : 35 , 'category' : 'chocolate', 'net weight' : '400 g'},
    20210926 : {'name' : 'Dark Fantasy Yummy Fills' , 'price' : 30.0, 'quantity' : 35 , 'category' : 'chocolate', 'net weight' : '400 g'},
    20210927 : {'name' : 'Jim Jam' , 'price' : 15.0, 'quantity' : 45 , 'category' : 'Biscuit', 'net weight' : '215 g'},
    20210928 : {'name' : '20 20' , 'price' : 20.0, 'quantity' : 40 , 'category' : 'Biscuit', 'net weight' : '197 g'},
    20210929 : {'name' : '5 Star' , 'price' : 10.0, 'quantity' : 45 , 'category' : 'chocolate', 'net weight' : '65 g'},
    20210930 : {'name' : '7 Up - 0.5 litre' , 'price' : 35.0, 'quantity' : 25 , 'category' : 'Juice', 'net weight' : '500 l'},
    20210931 : {'name': 'Jack & Jill', 'price': 15.0, 'quantity': 40, 'category': 'Snack','net weight' : '315 g',},
    20210932 : {'name': 'Oreo', 'price': 20.0, 'quantity': 45, 'category': 'Biscuit','net weight' : '215 g'}
}
f = open('IMS.json','w')         # OPENING JSON FILE IN WRITE MODE
f.write(json.dumps(products))    # WRITING DATA IN IT
f.close()                        # CLOSING JSON FILE

# %%
# CODE FOR INVENTORY MANAGEMENT SYSTEM

ch = ''

print('*'*20,' Welcome to ETG Super Market ','*'*20)

while ch != '6':
    
    with open('IMS.json' ,'r+') as file:
            data = json.loads(file.read())                   # LOADING THE DICTIONARY TO A VARIABLE FROM THE FILE
            
    ch = input('\nMAIN MENU' + 
           '\n\t1) View Items' + 
           '\n\t2) Add New Item' +                           # MAIN MENU
           '\n\t3) Buy An Item' +
           '\n\t4) Update An Item' +
           '\n\t5) Delete An Item' +
           '\n\t6) Exit' +
           '\nEnter (1/2/3/4/5/6) to select the options : ')
    
    
    if ch == '1':                                            # WHEN THE USER WANTS TO VIEW THE DETAILS OF ALL STOCKS
            for i in data:
                print('\nName : ', data[i]['name'] ,
                      '\tPrice : ', data[i]['price'] ,
                      '\tQuantity : ', data[i]['quantity'] ,
                      '\tCategory : ', data[i]['category'] ,
                      '\tNet Weight : ', data[i]['net weight'])
                
                
    elif ch == '2':                                          # WHEN THE USER NEEDS TO ADD AN ITEM
            name = input("\nEnter the New Item Name : ")
            price = float(input("Enter the New Item Price : "))
            quan = int(input("Enter the New Item Quantity : "))
            cat = input("Enter the New Item Category \n(chocolate/Snack/Juice/Nutrition Drink/Biscuit) : ")
            nweit = str(input("Entre the New Item Net Weight in grams(g)/liters(l) : "))
            
            pid = 20210900 + (len(data)+1)
            
            data.update({pid:{'name':name,'price':price,'quantity':quan,'category':cat,'net weight':nweit}})
            
            f = open('IMS.json','w')
            f.write(json.dumps(data))                # UPDATING THE JSON FILE
            f.close()
            
            print("\nNew Item Added...")
            
            
    elif ch == '3':                                         # WHEN THE COSTUMER NEEDS TO PURCHASE ANY ITEM
        count = 0
        pur = '1'
        plist = []
        tprice = 0.0
        for i in data:                                     # DISPLAY'S THE LIST OF PRODUCTS WITH THE PRICE AND PRODUCT ID
            print("\n",data[i]['name'] , " -> ","Cost : ", data[i]['price'] ," -> ", list(data.keys())[count])
            count+=1
            
        while(pur == '1'):                                 # WHILE LOOP IS FOR MULTIPLE PURCHASING
            name = ''
            while (name not in list(data.keys())):
                name = input("\nCopy & Paste the Id of the Product here... \nto Buy the product from the above list : ")
                                                           # GETS THE PRODUCT ID FOR ACCESSING THE PRODUCT DETAILS
                if name not in list(data.keys()):
                    print("\nInvalid name...Try Again ")
                    
            while True:
                quant = int(input("\nTotally " + str(data[name]['quantity']) + " stocks left"+
                          "\nEnter the Quantity of the product... \nYou need to buy : "))
                
                if quant>int(data[name]['quantity']):
                    print("\nThe Entered quantity is more than the stock... \nEnter the correct stock... ")
                    
                else : break
            tprice += quant * data[name]['price']
            print("Total Cost : ",quant * data[name]['price'])
            data[name]['quantity']-=quant
            
            plist.append(data[name]['name'] + " - " +str(quant))    # APPENDING THE DATA INTO THE LIST
            
            pur = input("\nEnter '1' to puchase 1 more item else give 'enter' key to exit : ")
            
        print("\nProcessing the purchase...")
        
        f = open('IMS.json','w')
        f.write(json.dumps(data))                # UPDATING THE JSON FILE
        f.close()
        
        print("\nPurchase Done...")
        
        print("\nPurchased Items : \n")
        count = 0
        for i in plist:                           # PRINTING THE PURCHASED ITEMS
            count+=1
            print(count, ". ",i)
        print("\nTotal Amount : ", tprice)
            
        print("\nThank's For Purchasing...\n Come Again... :)")
        
        
    elif ch == '4':                                        # WHEN THE USER NEEDS TO UPDATE ANY DETAIL A SPECIFIC ITEM
        count = 0
        
        for i in data:                                     # DISPLAY'S THE LIST OF PRODUCTS WITH PRODUCT ID
            print("\n",data[i]['name'] , "-> ", list(data.keys())[count])
            count+=1
            
        pid = ''
        while pid not in list(data.keys()):
            pid = input("\nCopy & Paste the Id of the Product here... \nto update the product from the above list : ")
                                                           # GETS THE PRODUCT ID FOR ACCESSING THE PRODUCT DETAILS
            if pid not in list(data.keys()):
                print("\nInvalid id...Try Again ")
                
        print("\nProduct Detail : ")
        print('\nName : ', data[pid]['name'] ,
                      '\nPrice : ', data[pid]['price'] ,
                      '\nQuantity : ', data[pid]['quantity'] ,
                      '\nCategory : ', data[pid]['category'] ,
                      '\tNet Weight : ', data[i]['net weight'])
        
        att = ''
        while att not in ['name','price','quantity','category','net weight']:
            att = input('\nEnter the attribute to be updated \n(name/price/quantity/category/net weight) :')
            att = att.lower()
            if att not in ['name','price','quantity','category','net weight']:
                print("\nINVALID ATTRIBUTE ... TRY AGAIN...")
                
        data[pid][att] = type(data[pid][att])(input('Enter the new value : '))          # GETS THE NEW DETAIL FROM THE USER...
                                                                                        # AND THE UPDATES THE DATA
        print("\nProcessing the update...")
        
        f = open('IMS.json','w')
        f.write(json.dumps(data))                # UPDATING THE JSON FILE
        f.close()
        
        print("Update Completed...")
                    
    elif ch == '5':                                        # WHEN THE USER NEEDS TO DELETE ANY DETAILS
        count = 0
        
        for i in data:                                     # DISPLAY'S THE LIST OF PRODUCTS WITH PRODUCT ID
            print("\n",data[i]['name'] , "-> ", list(data.keys())[count])
            count+=1
            
        pid =''
        while pid not in list(data.keys()):
                pid = input("\nCopy & Paste the Id of the Product here... \nto delete the product from the above list : ")
                                                           # GETS THE PRODUCT ID FOR ACCESSING THE PRODUCT DETAILS
                if pid not in list(data.keys()):
                    print("\nInvalid ID...Try Again ")
                    
        del data[pid]                            # DELETING THE PRODUCT DETAILS
        
        f = open('IMS.json','w')
        f.write(json.dumps(data))                # UPDATING THE JSON FILE
        f.close()
        
        print("\nItem Deleted Successfully...")
        
        
    elif ch == '6':                              # EXITING THE PROGRAM
        print("\nExiting...")
        print("Thank's For using Me ;)")
        
        
    else:
        print("\nInvalid Input... Try Again")      # FOR INVALID INPUT
